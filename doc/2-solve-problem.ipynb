# %% [markdown]
# # Solve Problem
#
# Load a benchmark problem and solve it with built-in solver, e.g., `GoogleORCPSolver`

# %%
from jsp import JSProblem
from jsp.solver import GoogleORCPSolver

# load benchmark problem
problem = JSProblem(benchmark='ft06')

# initialize solver
s = GoogleORCPSolver(problem=problem)

# %% [markdown]
# Call `JSSolver.solve(interval, callback)` to solve the problem.
# - `interval` A dynamic Gantt chart is shown during the solving process when `interval` is not None.
# - `callback` Call user defined function once a better solution is found.

# %%
s.solve(interval=2000,
    callback=lambda solution: print('current makespan: ', solution.makespan))

# NOTE: the solving process is running in a child-thread.
# wait and show result
s.wait()
print()
print('running:', s.is_running)
print('Solving time ', s.user_time)
print('Makespan ', s.solution.makespan)
# Out:
# current makespan:  88
# current makespan:  83
# current makespan:  81
# current makespan:  76
# current makespan:  65
# current makespan:  64
# current makespan:  63
# current makespan:  62
# current makespan:  60
# current makespan:  58
# current makespan:  57
# current makespan:  56
# current makespan:  55
# running: False
# Solving time  0.1
# Makespan  55

# %%
# explore solution
solution = s.solution
print('feasible solution:', solution.is_feasible)
for op in solution.ops:
    print('job=', op.source.job.id, 'machine=', op.source.machine.id, 'start_time=', op.start_time)
# Out:
# feasible solution: True
# job= 0 machine= 2 start_time= 0
# job= 0 machine= 0 start_time= 1
# job= 0 machine= 1 start_time= 16
# job= 0 machine= 3 start_time= 30
# job= 0 machine= 5 start_time= 37
# job= 0 machine= 4 start_time= 49
# job= 1 machine= 1 start_time= 0
# job= 1 machine= 2 start_time= 8
# job= 1 machine= 4 start_time= 13
# job= 1 machine= 5 start_time= 27
# job= 1 machine= 0 start_time= 40
# job= 1 machine= 3 start_time= 50
# job= 2 machine= 2 start_time= 1
# job= 2 machine= 3 start_time= 6
# job= 2 machine= 5 start_time= 10
# job= 2 machine= 0 start_time= 21
# job= 2 machine= 1 start_time= 30
# job= 2 machine= 4 start_time= 38
# job= 3 machine= 1 start_time= 11
# job= 3 machine= 0 start_time= 16
# job= 3 machine= 2 start_time= 22
# job= 3 machine= 3 start_time= 27
# job= 3 machine= 4 start_time= 30
# job= 3 machine= 5 start_time= 44
# job= 4 machine= 2 start_time= 13
# job= 4 machine= 1 start_time= 22
# job= 4 machine= 4 start_time= 25
# job= 4 machine= 5 start_time= 40
# job= 4 machine= 0 start_time= 50
# job= 4 machine= 3 start_time= 54
# job= 5 machine= 1 start_time= 8
# job= 5 machine= 3 start_time= 11
# job= 5 machine= 5 start_time= 18
# job= 5 machine= 0 start_time= 30
# job= 5 machine= 4 start_time= 45
# job= 5 machine= 2 start_time= 49

# %%
# explore solution: Gantt chart
solution.plot_gantt_chart()

# %%
# explore solution: disjunctive graph
solution.plot_disjunctive_graph()
