# %% [markdown]
# # Run Benchmark

# %%
import logging
from jsp import (JSProblem, JSSolution, BenchMark)
from jsp.solver import (GoogleORCPSolver, PriorityDispatchSolver, PuLPSolver)


def print_intermediate_solution(solution:JSSolution):
    '''User callback.'''
    logging.info('Makespan: %f', solution.makespan)



# ----------------------------------------
# create problem from benchmark
# ----------------------------------------
names = ['ft06', 'la01', 'ft10', 'swv01']
problems = [JSProblem(benchmark=name) for name in names]

# ----------------------------------------
# test built-in solver
# ----------------------------------------
# googl or-tools
s1 = GoogleORCPSolver(max_time=60)

# priority dispatching
s2 = PriorityDispatchSolver(rule='hh')

# PuLP solver
s3 = PuLPSolver(solver_name='SCIP', max_time=60)

# ----------------------------------------
# solve and result
# ----------------------------------------
benchmark = BenchMark(problems=problems, solvers=[s1,s2,s3], num_threads=6)
benchmark.run(show_info=True)
# Out:
# [2024-03-31 12:33:29 Runner_0] Start solving "ft06" with "or-tools"...
# [2024-03-31 12:33:29 Runner_1] Start solving "ft06" with "PriorityDispatchSolver"...
# [2024-03-31 12:33:29 Runner_2] Start solving "ft06" with "pulp"...
# [2024-03-31 12:33:29 Runner_3] Start solving "la01" with "or-tools"...
# [2024-03-31 12:33:29 Runner_4] Start solving "la01" with "PriorityDispatchSolver"...
# [2024-03-31 12:33:29 Runner_5] Start solving "la01" with "pulp"...
# [2024-03-31 12:33:29 Runner_1] Successfully to solve "ft06" with "PriorityDispatchSolver" in 0.000000 sec.
# [2024-03-31 12:33:29 Runner_4] Successfully to solve "la01" with "PriorityDispatchSolver" in 0.000000 sec.
# [2024-03-31 12:33:29 Runner_1] Start solving "ft10" with "or-tools"...
# [2024-03-31 12:33:29 Runner_4] Start solving "ft10" with "PriorityDispatchSolver"...
# [2024-03-31 12:33:29 Runner_4] Successfully to solve "ft10" with "PriorityDispatchSolver" in 0.000000 sec.
# [2024-03-31 12:33:29 Runner_4] Start solving "ft10" with "pulp"...
# [2024-03-31 12:33:29 Runner_3] Successfully to solve "la01" with "or-tools" in 0.200000 sec.
# [2024-03-31 12:33:29 Runner_0] Successfully to solve "ft06" with "or-tools" in 0.200000 sec.
# [2024-03-31 12:33:29 Runner_3] Start solving "swv01" with "or-tools"...
# [2024-03-31 12:33:29 Runner_0] Start solving "swv01" with "PriorityDispatchSolver"...
# [2024-03-31 12:33:29 Runner_0] Successfully to solve "swv01" with "PriorityDispatchSolver" in 0.200000 sec.
# [2024-03-31 12:33:29 Runner_0] Start solving "swv01" with "pulp"...
# [2024-03-31 12:33:48 Runner_1] Successfully to solve "ft10" with "or-tools" in 18.800000 sec.
# [2024-03-31 12:34:29 Runner_2] Successfully to solve "ft06" with "pulp" in 60.300000 sec.
# [2024-03-31 12:34:29 Runner_3] Successfully to solve "swv01" with "or-tools" in 60.200000 sec.
# Traceback (most recent call last):
#   File "d:\21_github\jsp-framework\jsp\model\solver.py", line 172, in __solving_thread
#     self.do_solve()
#   File "d:\21_github\jsp-framework\jsp\solver\pulp.py", line 57, in do_solve
#     raise JSPException('No feasible solution found.')
# jsp.common.exception.JSPException: No feasible solution found.
# [2024-03-31 12:34:44 Runner_5] Failed to solve "la01" with "pulp" in 74.700000 sec.
# Traceback (most recent call last):
#   File "d:\21_github\jsp-framework\jsp\model\solver.py", line 172, in __solving_thread
#     self.do_solve()
#   File "d:\21_github\jsp-framework\jsp\solver\pulp.py", line 57, in do_solve
#     raise JSPException('No feasible solution found.')
# jsp.common.exception.JSPException: No feasible solution found.
# [2024-03-31 12:34:44 Runner_4] Failed to solve "ft10" with "pulp" in 74.600000 sec.
# Traceback (most recent call last):
#   File "d:\21_github\jsp-framework\jsp\model\solver.py", line 172, in __solving_thread
#     self.do_solve()
#   File "d:\21_github\jsp-framework\jsp\solver\pulp.py", line 57, in do_solve
#     raise JSPException('No feasible solution found.')
# jsp.common.exception.JSPException: No feasible solution found.
# [2024-03-31 12:34:44 Runner_0] Failed to solve "swv01" with "pulp" in 74.300000 sec.
# [2024-03-31 12:34:44 MainThread]
# +----+---------+------------------------+---------------+---------+----------+---------+------+
# | ID | Problem |         Solver         | job x machine | Optimum | Solution | Error % | Time |
# +----+---------+------------------------+---------------+---------+----------+---------+------+
# | 1  |   ft06  |        or-tools        |     6 x 6     |    55   |    55    |   0.0   | 0.2  |
# | 2  |   ft06  | PriorityDispatchSolver |     6 x 6     |    55   |   60.0   |   9.1   | 0.0  |
# | 3  |   ft06  |          pulp          |     6 x 6     |    55   |   55.0   |   0.0   | 60.3 |
# | 4  |   la01  |        or-tools        |     10 x 5    |   666   |   666    |   0.0   | 0.2  |
# | 5  |   la01  | PriorityDispatchSolver |     10 x 5    |   666   |  666.0   |   0.0   | 0.0  |
# | 6  |   la01  |          pulp          |     10 x 5    |   666   | unsolved |   n.a.  | 74.7 |
# | 7  |   ft10  |        or-tools        |    10 x 10    |   930   |   930    |   0.0   | 18.8 |
# | 8  |   ft10  | PriorityDispatchSolver |    10 x 10    |   930   |  1082.0  |   16.3  | 0.0  |
# | 9  |   ft10  |          pulp          |    10 x 10    |   930   | unsolved |   n.a.  | 74.6 |
# | 10 |  swv01  |        or-tools        |    20 x 10    |   1407  |   1432   |   1.8   | 60.2 |
# | 11 |  swv01  | PriorityDispatchSolver |    20 x 10    |   1407  |  1839.0  |   30.7  | 0.2  |
# | 12 |  swv01  |          pulp          |    20 x 10    |   1407  | unsolved |   n.a.  | 74.3 |
# +----+---------+------------------------+---------------+---------+----------+---------+------+
